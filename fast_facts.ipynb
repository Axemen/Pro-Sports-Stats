# %%
import pandas as pd
from functools import reduce

# %%
mlb_stats = pd.read_csv("libs/unclean_data/mlb_war_ratings/mlb_war_ratings_all.csv")
mlb_stats.head(5)
# Out:
#    Unnamed: 0  k                      Player  WAR/pos  From    To    Age  \
# 0           0  1        Mike Trout\troutmi01     68.7  2011  2019  19-27
# 1           1  2      Robinson Cano\canoro01     45.4  2011  2019  28-36
# 2           2  3        Joey Votto\vottojo01     43.6  2011  2019  27-35
# 3           3  4     Adrian Beltre\beltrad01     43.2  2011  2018  32-39
# 4           4  5  Paul Goldschmidt\goldspa01     41.2  2011  2019  23-31
#
#       G    PA    AB     ...       SF  GDP   SB  CS     BA    OBP    SLG  \
# 0  1130  4962  4087     ...       46   56  196  35  0.306  0.419  0.575
# 1  1230  5292  4803     ...       32  155   31  15  0.299  0.358  0.492
# 2  1179  5152  4163     ...       36  110   47  18  0.307  0.433  0.511
# 3  1098  4612  4194     ...       49  101    8   3  0.304  0.357  0.509
# 4  1159  4998  4230     ...       37  103  124  33  0.296  0.395  0.526
#
#      OPS       Pos           Tm
# 0  0.994   *87/D9H          LAA
# ...

# %%
for i in range(len(mlb_stats)):
    mlb_stats.iat[i, 2] = mlb_stats.iat[i, 2].split('\\')[0]

# %%
mlb_stats.columns
# Out:
# Index(['Unnamed: 0', 'k', 'Player', 'WAR/pos', 'From', 'To', 'Age', 'G', 'PA',
#        'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH',
#        'SF', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'Pos', 'Tm'],
#       dtype='object')

# %%
mlb_salary = pd.read_csv("libs/unclean_data/mlb_player_salaries/mlb_player_salaries_all.csv")
mlb_salary.head(2)
# Out:
#    Unnamed: 0  rank  team                                         name  \
# 0           0   1.0   NaN  \n\nAlex Rodriguez\n\nDesignated Hitter\n\n
# 1           1   2.0   NaN           \n\nVernon Wells\n\nLeft Field\n\n
#
#          salary  year
# 0  $32,000,000   2011
# 1  $26,187,500   2011

# %%
for i in range(len(mlb_salary)):
    mlb_salary.iat[i,3] = mlb_salary.iat[i,3].strip().split('\n')[0].strip()

# %%
mlb_salary.head()
# Out:
#    Unnamed: 0  rank  team            name        salary  year
# 0           0   1.0   NaN  Alex Rodriguez  $32,000,000   2011
# 1           1   2.0   NaN    Vernon Wells  $26,187,500   2011
# 2           2   3.0   NaN   C.C. Sabathia  $25,571,428   2011
# 3           3   4.0   NaN   Mark Teixeira  $23,125,000   2011
# 4           4   5.0   NaN       Joe Mauer  $23,000,000   2011

# %%
mlb_salary.head(10)
# Out:
#    Unnamed: 0  rank  team          Player        salary  year
# 0           0   1.0   NaN  Alex Rodriguez  $32,000,000   2011
# 1           1   2.0   NaN  Alex Rodriguez  $26,187,500   2011
# 2           2   3.0   NaN  Alex Rodriguez  $25,571,428   2011
# 3           3   4.0   NaN  Alex Rodriguez  $23,125,000   2011
# 4           4   5.0   NaN  Alex Rodriguez  $23,000,000   2011
# 5           5   6.0   NaN  Alex Rodriguez  $22,500,000   2011
# 6           6   7.0   NaN  Alex Rodriguez  $20,171,428   2011
# 7           7   8.0   NaN  Alex Rodriguez  $20,000,000   2011
# 8           8   NaN   NaN  Alex Rodriguez  $20,000,000   2011
# 9           9   NaN   NaN  Alex Rodriguez  $20,000,000   2011

# %%
mlb_salary = mlb_salary.rename(columns={"name":"Player"})

# %%
mlb_merge = pd.merge(mlb_stats, mlb_salary, on='Player')

# %%
len(mlb_merge)
# Out:
# 9000

# %%
mlb_unis = pd.read_csv("libs/unclean_data/university_info/bb_players.csv")
mlb_unis.head(5)
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
mlb_unis = mlb_unis.rename(columns={"nameGiven":"Player"})
mlb_unis.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#            Player weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
mlb_schools = pd.read_csv("libs/unclean_data/university_info/mlb_player_unis.csv")
mlb_schools = mlb_schools.rename(columns={"nameGiven":"Player"})

# %%
mlb_schools.head()
# Out:
#     playerID                      name_full state           Player
# 0  aardsda01  Pennsylvania State University    PA      David Allan
# 1  aardsda01                Rice University    TX      David Allan
# 2   abadan01         Middle Georgia College    GA    Fausto Andres
# 3  abbeybe01          University of Vermont    VT        Bert Wood
# 4  abbotje01         University of Kentucky    KY  Jeffrey William

# %%
data_merged = data_merged.rename(columns={"name_full":"college"})
data_merged = data_merged.rename(columns={"WAR/pos":"wins_above_replacement"})

# %%
#mlb_merged = pd.merge(mlb_merge, mlb_unis, on='Player')
data = [mlb_unis, mlb_stats, mlb_salary, mlb_schools]
data_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Player'],
                                            how='outer'), data)

# %%
final_mlb = data_merged[["Player","salary","college", "state","wins_above_replacement"]]

# %%
data_merged.to_csv("libs/unclean_data/mlb_fast_facts_data1.csv")

# %% [markdown]
# Doing same funcitons with NBA files

# %%
nba_per = pd.read_csv("libs/unclean_data/nba_per_ratings/nba_per_ratings_all.csv")
nba_per.head(5)
# Out:
#    Unnamed: 0    Rk                   Player   Season  Age   Tm   Lg  PER  G  \
# 0           0  3801    Kalin Lucas\lucaska01  2014-15   25  MEM  NBA -0.7  1
# 1           1  3802  Matt Williams\willima05  2017-18   24  MIA  NBA -0.7  3
# 2           2  3803     Jeff Foote\footeje01  2011-12   24  NOH  NBA -0.9  4
# 3           3  3804  Shane Edwards\edwarsh01  2013-14   26  CLE  NBA -1.0  2
# 4           4  3805   Markel Brown\brownma02  2017-18   26  HOU  NBA -1.2  4
#
#    GS  ...    BLK  TOV  PF  PTS    FG%    2P%  3P%   eFG%  FT%    TS%
# 0   0  ...      0    0   1    0  0.000  0.000  NaN  0.000  NaN  0.000
# 1   0  ...      0    1   1    5  0.333  1.000  0.2  0.417  NaN  0.417
# 2   0  ...      1    2   5    4  0.333  0.333  NaN  0.333  NaN  0.333
# 3   0  ...      0    1   1    2  0.333  0.333  NaN  0.333  NaN  0.333
# 4   0  ...      0    2   6    5  0.286  0.500  0.2  0.357  NaN  0.357
#
# [5 rows x 34 columns]

# %%
nba_sal = pd.read_csv("libs/unclean_data/nba_player_salaries/nba_player_salaries_all.csv")
nba_sal.head(5)
# Out:
#    Unnamed: 0  rank  team                                          name  \
# 0           0   1.0   NaN    \r\r\nKobe Bryant\r\r\nSmall Forward\r\r\n
# 1           1   2.0   NaN  \r\r\nKevin Garnett\r\r\nPower Forward\r\r\n
# 2           2   3.0   NaN     \r\r\nTim Duncan\r\r\nPower Forward\r\r\n
# 3           3   4.0   NaN  \r\r\nRashard Lewis\r\r\nPower Forward\r\r\n
# 4           4   5.0   NaN  \r\r\nDirk Nowitzki\r\r\nPower Forward\r\r\n
#
#           salary  year
# 0  $25,244,493    2011
# 1  $21,247,044    2011
# 2  $21,164,619    2011
# 3  $21,136,631    2011
# 4  $19,092,873    2011

# %%
nba_sal.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'team', 'name', 'salary', 'year'], dtype='object')

# %%
for i in range(len(nba_per)):
    nba_per.iat[i, 2] = nba_per.iat[i, 2].split('\\')[0]

# %%
nba_per.head(5)
# Out:
#    Unnamed: 0    Rk         Player   Season  Age   Tm   Lg  PER  G  GS  ...    \
# 0           0  3801    Kalin Lucas  2014-15   25  MEM  NBA -0.7  1   0  ...
# 1           1  3802  Matt Williams  2017-18   24  MIA  NBA -0.7  3   0  ...
# 2           2  3803     Jeff Foote  2011-12   24  NOH  NBA -0.9  4   0  ...
# 3           3  3804  Shane Edwards  2013-14   26  CLE  NBA -1.0  2   0  ...
# 4           4  3805   Markel Brown  2017-18   26  HOU  NBA -1.2  4   0  ...
#
#    BLK  TOV  PF  PTS    FG%    2P%  3P%   eFG%  FT%    TS%
# 0    0    0   1    0  0.000  0.000  NaN  0.000  NaN  0.000
# 1    0    1   1    5  0.333  1.000  0.2  0.417  NaN  0.417
# 2    1    2   5    4  0.333  0.333  NaN  0.333  NaN  0.333
# 3    0    1   1    2  0.333  0.333  NaN  0.333  NaN  0.333
# 4    0    2   6    5  0.286  0.500  0.2  0.357  NaN  0.357
#
# [5 rows x 34 columns]

# %%
for i in range(len(nba_sal)):
    first = nba_sal['name'][0].strip().split('\n')[0].strip()
    nba_sal["name"] = first

# %%
nba_sal.head(5)
# Out:
#    Unnamed: 0  rank  team         name         salary  year
# 0           0   1.0   NaN  Kobe Bryant  $25,244,493    2011
# 1           1   2.0   NaN  Kobe Bryant  $21,247,044    2011
# 2           2   3.0   NaN  Kobe Bryant  $21,164,619    2011
# 3           3   4.0   NaN  Kobe Bryant  $21,136,631    2011
# 4           4   5.0   NaN  Kobe Bryant  $19,092,873    2011

# %%
nba_sal = nba_sal.rename(columns={"name":"Player"})

# %%
len(nba_sal)
# Out:
# 9000

# %%
nba_unis = pd.read_csv("libs/unclean_data/university_info/nba_player_unis.csv")
nba_unis.head(5)
# Out:
#    Unnamed: 0                     index            Player state
# 0           0         Acadia University      Brian Heaney   NaN
# 1           1    Alabama A&M University  Mickell Gladness    AL
# 2           2  Alabama State University       Kevin Loder    AL
# 3           3   Albany State University    Caldwell Jones    GA
# 4           4   Albany State University       Major Jones    GA

# %%
nba_df = [nba_unis, nba_sal, nba_per, nba_col] 
nba_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Player'],
                                            how='outer'), nba_df)

# %%
nba_merged.head()
# Out:
#    Unnamed: 0_x                     index            Player state  \
# 0           0.0         Acadia University      Brian Heaney   NaN
# 1           1.0    Alabama A&M University  Mickell Gladness    AL
# 2           1.0    Alabama A&M University  Mickell Gladness    AL
# 3           2.0  Alabama State University       Kevin Loder    AL
# 4           3.0   Albany State University    Caldwell Jones    GA
#
#    Unnamed: 0_y  rank  team salary  year  Unnamed: 0  ...     BLK  TOV    PF  \
# 0           NaN   NaN   NaN    NaN   NaN         NaN  ...     NaN  NaN   NaN
# 1           NaN   NaN   NaN    NaN   NaN      2961.0  ...    20.0  7.0  32.0
# 2           NaN   NaN   NaN    NaN   NaN      6561.0  ...    20.0  7.0  32.0
# 3           NaN   NaN   NaN    NaN   NaN         NaN  ...     NaN  NaN   NaN
# 4           NaN   NaN   NaN    NaN   NaN         NaN  ...     NaN  NaN   NaN
#
#     PTS    FG%    2P%  3P%   eFG%  FT%    TS%
# 0   NaN    NaN    NaN  NaN    NaN  NaN    NaN
# ...

# %%
nba_merged.to_csv("libs/unclean_data/nba_fast_facts_data.csv")

# %% [markdown]
# Doing same for NFL

# %%
nfl_av = pd.read_csv("libs/unclean_data/nfl_av_ratings/nfl_av_ratings_all.csv")
nfl_sal = pd.read_csv("libs/unclean_data/nfl_player_salaries/nfl_player_salaries_all.csv")
nfl_av.head(5)
# Out:
#    Unnamed: 0  Rk                  Player  From    To  Draft   Tm   Lg      G  \
# 0           0   1      Tom Brady\BradTo00  2009  2018  6-199  NWE  NFL  156.0
# 1           1   2     Drew Brees\BreeDr00  2009  2018   2-32  NOR  NFL  157.0
# 2           2   3  Aaron Rodgers\RodgAa00  2009  2018   1-24  GNB  NFL  142.0
# 3           3   4      Matt Ryan\RyanMa00  2009  2018    1-3  ATL  NFL  158.0
# 4           4   5  Philip Rivers\RivePh00  2009  2018    1-4  SDG  NFL  160.0
#
#       GS  Yrs  PB  AP1   AV
# 0  156.0   10  10    2  165
# 1  157.0   10   9    0  161
# 2  142.0   10   7    2  155
# 3  158.0   10   4    1  152
# 4  160.0   10   7    0  143

# %%
for i in range(len(nfl_av)):
    nfl_av.iat[i, 2] = nfl_av.iat[i, 2].split('\\')[0]

# %%
nfl_av.head(5)
# Out:
#    Unnamed: 0  Rk         Player  From    To  Draft   Tm   Lg      G     GS  \
# 0           0   1      Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0
# 1           1   2     Drew Brees  2009  2018   2-32  NOR  NFL  157.0  157.0
# 2           2   3  Aaron Rodgers  2009  2018   1-24  GNB  NFL  142.0  142.0
# 3           3   4      Matt Ryan  2009  2018    1-3  ATL  NFL  158.0  158.0
# 4           4   5  Philip Rivers  2009  2018    1-4  SDG  NFL  160.0  160.0
#
#    Yrs  PB  AP1   AV
# 0   10  10    2  165
# 1   10   9    0  161
# 2   10   7    2  155
# 3   10   4    1  152
# 4   10   7    0  143

# %%
nfl_sal.head(5)
# Out:
#                name         salary  year
# 0   Richard Seymour  $17,818,000    2011
# 1      Mark Sanchez  $17,228,125    2011
# 2    Dwight Freeney  $16,420,000    2011
# 3  Larry Fitzgerald  $16,250,000    2011
# 4    Mario Williams  $16,200,000    2011

# %%
nfl_sal = nfl_sal.rename(columns={"name":"Player"})
nfl_sal.head(5)
# Out:
#              Player         salary  year
# 0   Richard Seymour  $17,818,000    2011
# 1      Mark Sanchez  $17,228,125    2011
# 2    Dwight Freeney  $16,420,000    2011
# 3  Larry Fitzgerald  $16,250,000    2011
# 4    Mario Williams  $16,200,000    2011

# %%
nfl_merge = pd.merge(nfl_av, nfl_sal, on='Player')

# %%
nfl_merge.head(5)
# Out:
#    Unnamed: 0  Rk     Player  From    To  Draft   Tm   Lg      G     GS  Yrs  \
# 0           0   1  Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0   10
# 1           0   1  Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0   10
# 2           0   1  Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0   10
# 3           0   1  Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0   10
# 4           0   1  Tom Brady  2009  2018  6-199  NWE  NFL  156.0  156.0   10
#
#    PB  AP1   AV         salary  year
# 0  10    2  165  $12,950,000    2011
# 1  10    2  165  $12,950,000    2011
# 2  10    2  165   $8,000,000    2012
# 3  10    2  165  $13,800,000    2013
# 4  10    2  165  $14,800,000    2014

# %%
nfl_unis = pd.read_csv("libs/unclean_data/university_info/nfl_player_unis.csv")
nfl_unis.head(5)
# Out:
#    Unnamed: 0              index    college              name state
# 0           0  Allegheny College  Allegheny  Ronnie Anderson     PA
# 1           1  Allegheny College  Allegheny        Eddie Wall    PA
# 2           2       Alma College       Alma      Mark Konecny    MI
# 3           3    Amherst College    Amherst     Freddie Scott    MA
# 4           4    Amherst College    Amherst          Kid Hill    MA

# %%
nfl_unis = nfl_unis.rename(columns={"name":"Player"})
nfl_unis.head(5)
# Out:
#    Unnamed: 0              index    college            Player state
# 0           0  Allegheny College  Allegheny  Ronnie Anderson     PA
# 1           1  Allegheny College  Allegheny        Eddie Wall    PA
# 2           2       Alma College       Alma      Mark Konecny    MI
# 3           3    Amherst College    Amherst     Freddie Scott    MA
# 4           4    Amherst College    Amherst          Kid Hill    MA

# %%
#nfl_merge = pd.merge(nfl_merge, nfl_unis, on='Player')
#nfl_merge.to_csv("libs/unclean_data/nfl_fast_facts_data.csv")
nfl_data = pd.read_csv("libs/unclean_data/nfl_fast_facts_data1.csv")

# %%
nfl_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Rk      Player  From    To Draft   Tm   Lg  \
# 0           0             1   2  Drew Brees  2009  2018  2-32  NOR  NFL
# 1           1             1   2  Drew Brees  2009  2018  2-32  NOR  NFL
# 2           2             1   2  Drew Brees  2009  2018  2-32  NOR  NFL
# 3           3             1   2  Drew Brees  2009  2018  2-32  NOR  NFL
# 4           4             1   2  Drew Brees  2009  2018  2-32  NOR  NFL
#
#        G  ...   Yrs  PB  AP1   AV         salary  year  Unnamed: 0_y  \
# 0  157.0  ...    10   9    0  161  $12,574,700    2011          9398
# 1  157.0  ...    10   9    0  161  $12,574,700    2011          9398
# 2  157.0  ...    10   9    0  161  $10,400,000    2012          9398
# 3  157.0  ...    10   9    0  161  $17,400,000    2013          9398
# 4  157.0  ...    10   9    0  161  $18,400,000    2014          9398
#
#                index college state
# 0  Purdue University  Purdue    IN
# 1  Purdue University  Purdue    IN
# ...

# %%
nfl_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Rk', 'Player', 'From', 'To', 'Draft',
#        'Tm', 'Lg', 'G', 'GS', 'Yrs', 'PB', 'AP1', 'AV', 'salary', 'year',
#        'Unnamed: 0_y', 'index', 'college', 'state'],
#       dtype='object')

# %%
final_df = nfl_data[["Player","salary","college", "state","AV"]]

# %%
type(final_df)
# Out:
# pandas.core.frame.DataFrame

# %%
final_df.to_csv("libs/unclean_data/nfl_fast_facts_data2.csv")

# %%
nba_merged.columns
# Out:
# Index(['Unnamed: 0_x', 'index', 'Player', 'state', 'Unnamed: 0_y', 'rank',
#        'team', 'salary', 'year', 'Unnamed: 0', 'Rk', 'Season', 'Age', 'Tm',
#        'Lg', 'PER', 'G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA',
#        'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PTS', 'FG%', '2P%', '3P%', 'eFG%', 'FT%', 'TS%'],
#       dtype='object')

# %%
nba_col = pd.read_csv("libs/unclean_data/university_info/nba_player_universities.csv")

# %%
final_nba = nba_merged[["Player", "salary", "collage", "state", "PER"]]

# %%
final_nba = final_nba.rename(columns={"collage":"college"})

# %%
final_nba.to_csv("libs/unclean_data/nba_fast_facts_data1.csv")
